# %% [markdown]
# # Batch HydroLink
# ## Developed By: Daniel Wieferich (USGS)
# ## 20171005
#
# ### Note: This code is a work in progress.  Any suggestions and comments are welcomed.
# #### Also an issue was detected in the NHD High Resolution Services, which is returning no data when it should not.  This is currently being investigated with the NHD team.
#
# ### This code performs a hydrolink batch process on a text file (.csv ) or shapefile (.shp) using user defined latitude and longitude fields.  The code returns the reachcode and measure of the closest position on the High Resolution National Hydrography Dataset and the Medium Resolution NHDPlusV2.1 using web services.  The code also uses snap distance and stream name to help quantify a level of certainty.  Levels of certainty currently exist only for the NHDPlusV2.1, due to the availability of needed information from current web services.
#
# ### Next steps:
# 1. Work with the NHD High Resolution team to see if additional information can be returned from services to help with assigning a level of certainty. (in progress)
# 2. It would be great to get a measure of distance to closest confluence as a measure of certainty.  Through manual linkage in the past I've noticed that points within 50m of a confluence are more likely to link to the wrong reach.
# 3. The current code assumes lat/lon are in NAD83.  The code should be altered to accept various crs inputs.
# 4. Improve upon error checking and notifications
# 5. Allow for join of hydro-linked data to original dataset?

# %%
#The importFile function deals with importing csv or shps into a dataframe.  
def importFile (inputFileName, latFieldName, lonFieldName, streamFieldName, inputId):
    if inputFileName.endswith('.csv'):
        print ('\n' + 'reading csv file' +'\n')
        try:
            df = pd.read_csv(inputFileName)
        except KeyError:
            print ('file did not properly import, verify file name and rerun')
            #It would be nice here to reask for inputFileName and then restart at try statement
    elif inputFileName.endswith('.shp'):
        print('\n' + 'reading shapefile' + '\n')
        try:
            df = gp.GeoDataFrame.from_file(inputFileName)
        except KeyError:
            print ('file did not properly import, verify file name and rerun')
            #It would be nice here to reask for inputFileName and then restart at try statement
    else:
        print('File type not currently accepted. Please try .csv or .shp')
        
    if latFieldName in df and lonFieldName in df and streamFieldName in df and inputId in df:
        df = df[[inputId, latFieldName, lonFieldName, streamFieldName]].copy()
        df = df.rename(columns={inputId: 'id', latFieldName: 'lat', lonFieldName: 'lon', streamFieldName: 'stream'})
        return df
    else: 
        print ('verify field names and rerun')
        
#Using initial lat,lon (in nad83) to link to High Resolution NHD
def hydrolinkHr(lat,lon,inputId):
    baseUrlHR = 'https://edits.nationalmap.gov/arcgis/rest/services/HEM/NHDHigh/MapServer/'
    getHrReach = baseUrlHR + 'exts/HEM_EditEvents_SOE/HEMGetReachcodeFromXY'
    getHrX = baseUrlHR + 'exts/HEM_EditEvents_SOE/HEMPointEvents'
    
    #Define variables, set initially as null values using similar denotation as the HydroLink Tool
    reachcodeHr = 'NO REACHCODE'
    measHigh = -999
    smDateHigh = ' '
    permId = 'NO PERM ID'
    xyHigh = '-999'
    
    #Structure original lat/lon into format needed for HEM SOE
    xy = '{"x":' + str(lon) + ',"y":' + str(lat) + ', "spatialReference": {"wkid":4269}}'
    
    if lat and (float(lat) > 24 and float(lat)<50) and lon and (float(lon) < -66 and float(lon)> -125):
        payload = {
            "point": xy ,
            "selectionLayerName": "NHDFLOWLINE",
            "selectionType": "TOPDOWNSTREAM",
            "searchToleranceMeters": 10000,
            "outWKID": 4269,
            "f": "json"}
        
        #Connects to web service
        r = requests.post(getHrReach,params=payload,verify=False).json()
        
        try:
            
                if r['resultStatus'] == 'success' and r['features']:
                    reachcodeHr = r['features'][0]['attributes']['REACHCODE']
                    payload2 = {
                      "point": xy ,
                      "reachcode": reachcodeHr,
                      "outWKID": 4269,
                      "f": "json"}

                    r2 = requests.post(getHrX,params=payload2,verify=False).json()
                    measHigh = r2['features'][0]['attributes']['MEASURE']
                    smDateHigh = r2['features'][0]['attributes']['REACHSMDATE']
                    permId = r2['features'][0]['attributes']['PERMANENT_IDENTIFIER']
                    xyHigh = r2['features'][0]['geometry']
                    return (reachcodeHr,measHigh,smDateHigh,permId,xyHigh)

                else:
                    return (reachcodeHr,measHigh,smDateHigh,permId,xyHigh)
        except:
            print ('Failed to process HR for: ' + str(inputId))
            return (reachcodeHr,measHigh,smDateHigh,permId,xyHigh)
    else:
        return (reachcodeHr,measHigh,smDateHigh,permId,xyHigh)

        
def hydrolinkMr(lat,lon,inputId):
    
    #Define variables, set initially as null values using similar denotation as the HydroLink Tool
    snapDist = -999
    xyMed = ''
    comidMed = 'NO COMID'
    reachMed = 'NO REACHCODE'
    measMed = -999
    gnisMed = ''
    
    #Additional Info about medium resolution service : https://www.epa.gov/waterdata/point-indexing-service
    xyMed = 'POINT(' + str(lon) + ' ' + str(lat) + ')'
    
    payloadMr = {
        'optNHDPlusDataset': '2.1',
        'pGeometry': xyMed,
        'pGeometryMod': 'SRID=8265',
        'pOutputPathFlag': 'TRUE',
        'pPointIndexingMaxDist': '2', #Kilometers
        'pPointIndexingMethod':'DISTANCE',
        'pResolution': '3',
        'pPointIndexingFcodeDeny' : [56600],
        'pReturnFlowlineGeomFlag':'FALSE',
        'f':'json'}
    
    baseUrlMr = 'https://ofmpub.epa.gov/waters10/PointIndexing.Service'
    
    #Connects to web service
    rMed = requests.post(baseUrlMr,params=payloadMr, verify=False).json()
    
    try:
        snapDist = rMed['output']['total_distance']
        xyMed = rMed['output']['end_point']['coordinates']
        comidMed = rMed['output']['ary_flowlines'][0]['comid']
        reachMed = rMed['output']['ary_flowlines'][0]['reachcode']
        measMed = rMed['output']['ary_flowlines'][0]['fmeasure']
        gnisMed = rMed['output']['ary_flowlines'][0]['gnis_name']
        return (snapDist,xyMed,comidMed,reachMed,measMed,gnisMed)
       
    except:
        print 
        return (snapDist,xyMed,comidMed,reachMed,measMed,gnisMed)
    

def cleanStreamName(stream):
    
    if stream:
        #remove case for case sensitive operations
        stream = stream.lower()
        
        #replace common abbreviations, this needs improvement but be careful not to replace strings we dont want to
        #this code currently assumes GNIS_NAME never contains abbreviations... something to verify
        #If you have a better way to do this let me know!!!!
        stream = stream.replace(' st ', 'stream')
        stream = stream.replace(' st.', 'stream')
        stream = stream.replace(' rv ', 'river')
        stream = stream.replace(' rv.', 'river')
        stream = stream.replace(' trib.', 'tributary')
        stream = stream.replace(' trib)', 'tributary')
        stream = stream.replace(' trib ', 'tributary')
        stream = stream.replace(' ck ', 'creek')
        stream = stream.replace(' ck.', 'creek')
        stream = stream.replace(' br ', 'branch')
        stream = stream.replace(' br.', 'branch')
        
        return stream
    else:
        return stream
                       
def mrCertainty(streamClean, gnisMed):
    import difflib
    
    
    #Stream Name Match
    if streamClean and gnisMed:
        gnisMed = gnisMed.lower()
        #print ('\n' + gnisMed)
        #print (streamClean)

        if gnisMed == streamClean:
            gnisCertMr = 1
            #print (gnisCert)
        #do not want name of main stem to be fuzzy matched.  To avoid remove those names with tributary or branch in them
        elif 'tributary' in streamClean or 'branch' in streamClean:
            gnisCertMr = 0
            #print (gnisCert)
        else:
            matchRatio = difflib.SequenceMatcher(lambda x: x == " ",streamClean, gnisMed).ratio()
            
            # From Python Documentation (https://docs.python.org/3/library/difflib.html):
            #"As a rule of thumb, a ratio() value over 0.6 means the sequences are close matches:"
            # At some point we should validate this rule of thumb but figured this is a good starting place
            if matchRatio >= 0.6:
                gnisCertMr = 1
                #print (gnisCert)
            #this is likely a match but less certain
            elif 0.6 > matchRatio >= 0.5:
                gnisCertMr = 0.5
                #print (gnisCert)
            else:
                gnisCertMr = 0
                #print (gnisCert)
                
    #else no stream name is supplied for one or both datasets, therefor stream name does not help improve certainty
    else:
        gnisCertMr = 0
    #--------------------------------------------------------------------   
    #Distance between original lat/lon and reach/measure linkage
    #Note: snapDist is returned in Kilometers
    if snapDist or snapDist==0:
        #print (snapDist)
        if snapDist == -999:
            distCertMr = 0
            #print (distCertMr)
        elif snapDist <=0.050:
            distCertMr = 1
            #print (distCertMr)
        elif 0.200<= snapDist <0.050:
            distCertMr = 0.5
            #print (distCertMr)
        else:
            distCertMr = 0
            #print (distCertMr)
    else:
        distCertMr = 0
        
        
    #ADD CODE TO CHECK DISTANCE TO CLOSEST CONFLUENCE, if less than ?50m? flag as needs visual confirmation
           
        
    return gnisCertMr, distCertMr

# %%
import requests
import json
import geopandas as gp
import pandas as pd
import warnings

warnings.filterwarnings("ignore")

#User inputs variables needed for code to run
#inputFileName = input("Enter file name, including extension (only accepts .csv and .shp): ")
#latFieldName = input("Enter field name for latitude, note this is case sensitive: ")
#lonFieldName = input("Enter field name for longitude, note this is case sensitive: ")
#streamFieldName = input("Enter field name for stream name, note this is case sensitive: ")
#inputId = input("Enter field name for identifier, note this is case sensitive: ")

#Alternative to user input, info can be hard coded here
#inputFileName = 'testData/test2.shp'
#latFieldName = 'DamLatitud'
#lonFieldName = 'DamLongitu'
#streamFieldName = 'DamRiverNa'
#inputId = 'DamName'

#Alternative to user input, info can be hard coded here
inputFileName = 'testAR.csv'
latFieldName = 'lat'
lonFieldName = 'lon'
streamFieldName = 'riv'
inputId = 'uniqueId'


outData = []

df = importFile(inputFileName, latFieldName, lonFieldName, streamFieldName, inputId)

for row in df.itertuples():
        
        #Define variables based on row,field values
        lat = row.lat
        lon = row.lon
        inputId = row.id
        stream = str(row.stream)
        
        print ('working on : ' + str(inputId))
                
        reachcodeHr,measHigh,smDateHigh,permId,xyHigh = hydrolinkHr(lat,lon,inputId)
        snapDist,xyMed,comidMed,reachMed,measMed,gnisMed = hydrolinkMr(lat,lon,inputId)
        streamClean = cleanStreamName(stream)
        gnisCertMr, distCertMr = mrCertainty(streamClean, gnisMed)
        
        #record data in outData, this will be used to create dataframe
        outData.append({"id":inputId,"ReachHigh":reachcodeHr,"ReachMed":reachMed,"MeasHigh":measHigh,"MeasMed":measMed,"SmdateHigh":smDateHigh, "Comid":comidMed, "permIdHr": permId, "xyHigh":xyHigh, "xyMed":xyMed,"gnisCertMr":gnisCertMr, "distCertMr":distCertMr, "gnisNameM": gnisMed })

#Create Dataframe with hydro-link data        
outDf = pd.DataFrame(outData)
# Out:
# reading csv file
#
# working on : AK-001
# working on : AK-002
# working on : AK-003
# working on : AK-004
# working on : AK-005
# working on : AK-006
# working on : AK-007
# working on : AK-008
# working on : AK-009
# working on : AL-001
# working on : AL-002
# working on : AL-003
# working on : AL-004
# working on : AL-005
# working on : AL-006
# working on : AR-001
# working on : AR-002
# working on : AR-003
# working on : AR-004
# working on : AZ-002
# working on : AZ-003
# working on : AZ-004
# working on : CA-001
# working on : CA-002
# working on : CA-003
# working on : CA-004
# working on : CA-005
# working on : CA-006
# working on : CA-007
# working on : CA-008
# working on : CA-009
# working on : CA-010
# working on : CA-011
# working on : CA-012
# working on : CA-013
# working on : CA-014
# working on : CA-015
# working on : CA-016
# working on : CA-017
# working on : CA-018
# working on : CA-019
# working on : CA-020
# working on : CA-021
# working on : CA-022
# working on : CA-023
# working on : CA-024
# working on : CA-025
# working on : CA-026
# working on : CA-027
# working on : CA-028
# working on : CA-029
# working on : CA-030
# working on : CA-031
# working on : CA-032
# working on : CA-033
# working on : CA-034
# working on : CA-035
# working on : CA-036
# working on : CA-037
# working on : CA-038
# working on : CA-039
# working on : CA-040
# working on : CA-041
# working on : CA-042
# working on : CA-043
# working on : CA-044
# working on : CA-045
# working on : CA-046
# working on : CA-047
# working on : CA-048
# working on : CA-049
# working on : CA-050
# working on : CA-051
# working on : CA-052
# working on : CA-053
# working on : CA-054
# working on : CA-055
# working on : CA-056
# working on : CA-057
# working on : CA-058
# working on : CA-059
# working on : CA-060
# working on : CA-061
# working on : CA-062
# working on : CA-063
# working on : CA-064
# working on : CA-065
# working on : CA-066
# working on : CA-067
# working on : CA-068
# working on : CA-069
# working on : CA-070
# Failed to process HR for: CA-070
# working on : CA-071
# working on : CA-072
# working on : CA-073
# working on : CA-074
# working on : CA-075
# working on : CA-076
# working on : CA-077
# working on : CA-078
# working on : CA-079
# working on : CA-080
# working on : CA-081
# working on : CA-082
# working on : CA-083
# working on : CA-084
# working on : CA-085
# working on : CA-086
# working on : CA-087
# working on : CA-088
# Failed to process HR for: CA-088
# working on : CA-089
# working on : CA-090
# working on : CA-091
# working on : CA-092
# working on : CA-093
# working on : CA-094
# working on : CA-095
# working on : CA-096
# working on : CA-097
# working on : CA-098
# working on : CA-099
# working on : CA-100
# working on : CA-101
# working on : CO-001
# working on : CO-002
# working on : CO-003
# working on : CO-004
# working on : CO-005
# working on : CO-006
# working on : CO-007
# working on : CO-008
# working on : CO-009
# working on : CO-010
# working on : CO-011
# working on : CO-012
# working on : CO-013
# working on : CO-014
# working on : CO-015
# working on : CO-016
# working on : CO-017
# working on : CO-018
# working on : CO-019
# working on : CO-020
# working on : CO-021
# working on : CT-001
# working on : CT-002
# working on : CT-003
# working on : CT-004
# working on : CT-005
# working on : CT-006
# working on : CT-007
# working on : CT-008
# working on : CT-009
# working on : CT-010
# working on : CT-011
# working on : CT-012
# working on : CT-013
# working on : CT-014
# working on : CT-015
# working on : CT-016
# working on : CT-017
# working on : CT-018
# working on : CT-019
# working on : CT-020
# working on : CT-021
# Failed to process HR for: CT-021
# working on : CT-022
# working on : CT-023
# working on : CT-024
# working on : CT-025
# working on : CT-026
# working on : CT-027
# working on : CT-028
# working on : CT-029
# Failed to process HR for: CT-029
# working on : CT-030
# working on : CT-031
# working on : CT-032
# working on : CT-033
# working on : CT-034
# working on : CT-035
# working on : DC-001
# working on : DC-002
# working on : DC-003
# working on : DC-004
# working on : DE-001
# working on : FL-001
# working on : FL-002
# working on : FL-003
# working on : FL-004
# working on : FL-005
# working on : FL-006
# working on : GA-001
# working on : GA-002
# working on : HI-001
# working on : HI-002
# working on : HI-003
# working on : HI-004
# working on : HI-005
# working on : HI-006
# working on : HI-007
# working on : HI-008
# working on : HI-009
# working on : HI-010
# working on : HI-011
# working on : HI-012
# working on : HI-013
# working on : HI-014
# working on : HI-015
# working on : HI-016
# working on : HI-017
# working on : HI-018
# working on : IA-001
# working on : IA-002
# working on : IA-003
# working on : IA-004
# working on : IA-005
# working on : IA-006
# working on : IA-007
# working on : IA-008
# working on : ID-001
# working on : ID-002
# working on : ID-003
# working on : ID-004
# working on : ID-005
# working on : ID-006
# working on : ID-007
# working on : ID-008
# working on : ID-010
# working on : ID-011
# working on : ID-012
# working on : ID-013
# working on : ID-014
# working on : ID-015
# working on : ID-016
# working on : ID-017
# working on : ID-018
# working on : ID-019
# working on : ID-020
# working on : ID-021
# Failed to process HR for: ID-021
# working on : ID-022
# working on : IL-001
# working on : IL-002
# working on : IL-004
# working on : IL-006
# working on : IL-007
# working on : IL-008
# working on : IL-009
# working on : IL-010
# working on : IL-012
# working on : IL-013
# working on : IL-014
# working on : IL-015
# working on : IL-016
# working on : IL-017
# working on : IL-018
# working on : IL-019
# working on : IL-020
# working on : IL-021
# working on : IL-022
# working on : IL-023
# working on : IL-024
# working on : IL-025
# working on : IL-026
# working on : IL-027
# working on : IL-028
# working on : IL-029
# working on : IL-030
# working on : IL-031
# working on : IL-032
# working on : IL-033
# working on : IL-034
# working on : IL-035
# working on : IL-036
# working on : IL-037
# working on : IL-038
# working on : IL-039
# working on : IL-040
# working on : IL-041
# working on : IL-042
# working on : IL-043
# working on : IL-044
# working on : IN-001
# working on : IN-002
# working on : IN-003
# working on : IN-004
# working on : IN-005
# working on : KS-001
# working on : KS-002
# working on : KS-003
# working on : KS-004
# working on : KS-005
# working on : KS-006
# working on : KS-007
# working on : KY-001
# working on : KY-002
# working on : KY-003
# working on : KY-004
# working on : LA-001
# working on : LA-002
# working on : LA-003
# working on : MA-001
# working on : MA-002
# working on : MA-003
# working on : MA-004
# working on : MA-005
# working on : MA-006
# working on : MA-007
# working on : MA-008
# working on : MA-009
# Failed to process HR for: MA-009
# working on : MA-010 to MA-016
# working on : MA-017
# working on : MA-018
# working on : MA-019
# working on : MA-020
# working on : MA-021
# working on : MA-022
# working on : MA-023
# working on : MA-024
# working on : MA-025
# working on : MA-026
# working on : MA-027
# working on : MA-028
# working on : MA-029
# working on : MA-030
# working on : MA-031
# working on : MA-032
# working on : MA-033
# working on : MA-034
# working on : MA-035
# working on : MA-036
# working on : MA-037
# working on : MA-038
# working on : MA-039
# working on : MA-040
# working on : MA-041
# Failed to process HR for: MA-041
# working on : MA-042
# working on : MA-043
# Failed to process HR for: MA-043
# working on : MA-044
# working on : MA-045
# working on : MA-046
# working on : MA-047
# working on : MA-048
# working on : MA-049
# working on : MA-050
# working on : MA-051
# working on : MD-001
# working on : MD-002
# working on : MD-003
# working on : MD-004
# working on : MD-005
# working on : MD-006
# working on : MD-007
# working on : MD-008
# working on : MD-009
# working on : MD-010
# working on : MD-011
# working on : MD-012
# working on : MD-013
# working on : MD-014
# working on : MD-015
# working on : MD-016
# working on : MD-017
# working on : MD-018
# Failed to process HR for: MD-018
# working on : MD-019
# working on : MD-020
# working on : ME-001
# working on : ME-002
# working on : ME-003
# working on : ME-004
# working on : ME-005
# working on : ME-006
# working on : ME-007
# working on : ME-008
# working on : ME-010
# working on : ME-011
# Failed to process HR for: ME-011
# working on : ME-012
# working on : ME-013
# working on : ME-014
# working on : ME-015
# working on : ME-016
# working on : ME-017
# working on : ME-018
# working on : ME-019
# working on : ME-020
# working on : ME-021
# working on : ME-022
# Failed to process HR for: ME-022
# working on : ME-023
# working on : ME-024
# working on : ME-025
# working on : ME-026
# working on : ME-027
# working on : ME-028
# working on : ME-029
# working on : ME-030
# working on : ME-031
# working on : ME-032
# working on : ME-033
# working on : ME-034
# working on : MI-001
# working on : MI-002
# working on : MI-003
# working on : MI-004
# working on : MI-005
# working on : MI-006
# working on : MI-007
# working on : MI-008
# working on : MI-009
# working on : MI-010
# working on : MI-011
# working on : MI-012
# working on : MI-013
# working on : MI-014
# working on : MI-015
# working on : MI-016
# working on : MI-017
# working on : MI-018
# working on : MI-019
# working on : MI-020
# working on : MI-021
# working on : MI-022
# working on : MI-023
# working on : MI-024
# working on : MI-025
# working on : MI-026
# working on : MI-027
# working on : MI-028
# working on : MI-029
# working on : MI-030
# working on : MI-032
# working on : MI-033
# Failed to process HR for: MI-033
# working on : MI-034
# working on : MI-035
# working on : MI-036
# working on : MI-038
# working on : MI-039
# working on : MI-040
# working on : MI-041
# working on : MI-042
# working on : MI-043
# working on : MI-044
# working on : MI-045
# working on : MI-046
# working on : MI-047
# working on : MI-048
# working on : MI-049
# working on : MI-050
# working on : MI-051
# Failed to process HR for: MI-051
# working on : MI-052
# working on : MI-053
# working on : MI-054
# working on : MI-055
# working on : MI-056
# working on : MI-057
# working on : MI-058
# working on : MI-059
# working on : MI-060
# Failed to process HR for: MI-060
# working on : MI-061
# working on : MI-062
# Failed to process HR for: MI-062
# working on : MI-063
# working on : MI-064
# working on : MI-065
# working on : MI-066
# working on : MI-067
# working on : MI-068
# working on : MI-069
# working on : MI-070
# working on : MI-071
# working on : MN-001
# working on : MN-002
# working on : MN-003
# working on : MN-004
# working on : MN-005
# working on : MN-006
# working on : MN-007
# working on : MN-008
# working on : MN-009
# working on : MN-010
# Failed to process HR for: MN-010
# working on : MN-011
# working on : MN-012
# working on : MN-013
# working on : MN-014
# working on : MN-015
# working on : MN-016
# working on : MN-017
# working on : MN-018
# working on : MN-019
# working on : MN-020
# working on : MN-021
# working on : MN-022
# working on : MN-023
# working on : MN-024
# working on : MN-025
# working on : MN-026
# working on : MN-027
# working on : MN-028
# working on : MN-029
# working on : MN-030
# working on : MN-031
# working on : MN-032
# working on : MN-033
# working on : MN-034
# working on : MN-035
# working on : MN-036
# working on : MN-037
# working on : MN-038
# working on : MN-039
# working on : MN-040
# Failed to process HR for: MN-040
# working on : MN-041
# working on : MN-042
# working on : MN-043
# working on : MN-044
# working on : MN-045
# working on : MN-046
# working on : MN-047
# working on : MN-048
# working on : MN-049
# working on : MO-001
# working on : MO-002
# working on : MT-001
# working on : MT-002
# working on : MT-003
# working on : MT-004
# working on : MT-005
# working on : MT-006
# working on : MT-007
# Failed to process HR for: MT-007
# working on : MT-008
# working on : MT-009
# working on : MT-010
# working on : MT-011
# working on : NC-001
# working on : NC-002
# working on : NC-003
# working on : NC-004
# working on : NC-005
# working on : NC-006
# working on : NC-007
# working on : NC-008
# working on : NC-009
# working on : NC-010
# working on : NC-011
# working on : NC-012
# working on : NC-013
# working on : NC-014
# Failed to process HR for: NC-014
# working on : NC-015
# working on : NC-016
# working on : NC-017
# working on : NC-018
# working on : NC-019
# working on : NC-020
# working on : NC-021
# working on : NC-022
# working on : NC-023
# working on : NC-024
# working on : NC-025
# working on : NC-026
# working on : NC-027
# working on : NC-028
# working on : NC-029
# working on : ND-002
# working on : ND-003
# working on : NE-001
# working on : NE-003
# working on : NE-004
# working on : NE-005
# working on : NE-006
# working on : NH-001
# working on : NH-002
# working on : NH-003
# working on : NH-004
# working on : NH-005
# working on : NH-006
# working on : NH-007
# working on : NH-008
# Failed to process HR for: NH-008
# working on : NH-009
# working on : NH-010
# working on : NH-011
# working on : NH-012
# working on : NH-013
# working on : NH-014
# working on : NH-015
# working on : NH-016
# Failed to process HR for: NH-016
# working on : NH-017
# working on : NH-018
# working on : NH-019
# working on : NH-020
# working on : NH-021
# working on : NH-022
# working on : NH-023
# working on : NH-024
# working on : NH-025
# Failed to process HR for: NH-025
# working on : NH-026
# working on : NH-027
# working on : NH-028
# working on : NH-029
# working on : NH-030
# working on : NH-031
# working on : NH-032
# working on : NH-033
# working on : NJ-001
# working on : NJ-002
# working on : NJ-003
# working on : NJ-004
# working on : NJ-005
# working on : NJ-006
# working on : NJ-007
# working on : NJ-008
# working on : NJ-009
# working on : NJ-010
# working on : NJ-011
# working on : NJ-012
# working on : NJ-013
# working on : NJ-014
# working on : NJ-015
# working on : NJ-016
# working on : NJ-017
# working on : NJ-018
# working on : NJ-019
# working on : NJ-020
# Failed to process HR for: NJ-020
# working on : NJ-021
# Failed to process HR for: NJ-021
# working on : NJ-022
# working on : NJ-023
# working on : NJ-024
# working on : NJ-025
# working on : NJ-026
# working on : NJ-027
# working on : NJ-028
# working on : NJ-029
# Failed to process HR for: NJ-029
# working on : NJ-030
# working on : NJ-031
# working on : NJ-032
# working on : NJ-033
# working on : NJ-034
# working on : NJ-035
# working on : NJ-036
# working on : NM-001
# working on : NM-002
# working on : NY-001
# working on : NY-002
# working on : NY-003
# working on : NY-004
# working on : NY-005
# working on : NY-006
# working on : NY-007
# working on : NY-008
# working on : NY-009
# working on : NY-010
# working on : NY-011
# working on : NY-012
# working on : NY-013
# working on : NY-014
# working on : NY-015
# working on : NY-016
# Failed to process HR for: NY-016
# working on : NY-017
# working on : NY-018
# working on : NY-019
# working on : NY-020
# working on : NY-021
# Failed to process HR for: NY-021
# working on : NY-022
# working on : NY-023
# working on : NY-024
# working on : NY-025
# working on : NY-026
# working on : NY-027
# Failed to process HR for: NY-027
# working on : NY-028
# working on : NY-029
# Failed to process HR for: NY-029
# working on : NY-030
# Failed to process HR for: NY-030
# working on : NY-031
# working on : OH-001
# working on : OH-002
# working on : OH-003
# working on : OH-004
# working on : OH-005
# working on : OH-006
# Failed to process HR for: OH-006
# working on : OH-007
# working on : OH-008
# working on : OH-009
# working on : OH-010
# working on : OH-011
# working on : OH-012
# working on : OH-013
# working on : OH-014
# working on : OH-015
# working on : OH-016
# Failed to process HR for: OH-016
# working on : OH-017
# working on : OH-018
# working on : OH-019
# working on : OH-020
# working on : OH-021
# working on : OH-022
# working on : OH-023
# working on : OH-024
# working on : OH-027
# working on : OH-028
# working on : OH-029
# working on : OH-030
# working on : OH-031
# working on : OH-032
# working on : OH-033
# working on : OH-034
# working on : OH-035
# working on : OH-036
# working on : OH-037
# working on : OH-038
# working on : OH-039
# working on : OH-040
# working on : OH-041
# working on : OH-042
# working on : OH-043
# working on : OH-044
# Failed to process HR for: OH-044
# working on : OH-045
# working on : OH-046
# working on : OH-047
# working on : OH-048
# working on : OH-049
# working on : OH-050
# working on : OH-051
# working on : OH-052
# working on : OH-053
# working on : OH-054
# working on : OH-055
# working on : OH-056
# working on : OH-057
# working on : OH-058
# working on : OH-059
# working on : OH-060
# working on : OH-061
# working on : OH-062
# working on : OH-063
# working on : OR-001
# working on : OR-002
# working on : OR-003
# working on : OR-004
# working on : OR-005
# working on : OR-006
# working on : OR-007
# working on : OR-008
# Failed to process HR for: OR-008
# working on : OR-009
# working on : OR-010
# working on : OR-011
# working on : OR-012
# working on : OR-013
# Failed to process HR for: OR-013
# working on : OR-014
# working on : OR-015
# working on : OR-016
# working on : OR-017
# working on : OR-018
# working on : OR-019
# working on : OR-020
# working on : OR-021
# working on : OR-022
# Failed to process HR for: OR-022
# working on : OR-023
# working on : OR-024
# working on : OR-025
# working on : OR-026
# working on : OR-027
# working on : OR-028
# working on : OR-029
# working on : OR-030
# working on : OR-031
# working on : OR-032
# working on : OR-033
# working on : OR-034
# working on : OR-035
# working on : OR-036
# working on : OR-037
# working on : OR-038
# working on : OR-039
# working on : OR-040
# working on : OR-041
# working on : OR-042
# working on : OR-043
# Failed to process HR for: OR-043
# working on : OR-044
# working on : OR-045
# working on : OR-046
# working on : OR-047
# working on : OR-048
# working on : OR-049
# working on : OR-050
# working on : OR-051
# working on : OR-052
# working on : PA-001
# working on : PA-002
# working on : PA-003
# working on : PA-004
# working on : PA-005
# working on : PA-006
# working on : PA-007
# working on : PA-008
# working on : PA-009
# working on : PA-010
# working on : PA-011
# working on : PA-012
# working on : PA-013
# working on : PA-014
# working on : PA-015
# working on : PA-016
# working on : PA-017
# working on : PA-018
# working on : PA-019
# working on : PA-020
# working on : PA-021
# working on : PA-022
# working on : PA-023
# working on : PA-024
# working on : PA-025
# working on : PA-026
# Failed to process HR for: PA-026
# working on : PA-027
# working on : PA-028
# working on : PA-029
# working on : PA-030
# working on : PA-031
# working on : PA-032
# working on : PA-033
# working on : PA-034
# working on : PA-035
# working on : PA-036
# working on : PA-037
# working on : PA-038
# working on : PA-039
# working on : PA-040
# working on : PA-041
# working on : PA-042
# working on : PA-043
# working on : PA-044
# working on : PA-045
# working on : PA-046
# working on : PA-047
# Failed to process HR for: PA-047
# working on : PA-048
# working on : PA-049
# working on : PA-050
# working on : PA-051
# working on : PA-052
# working on : PA-053
# working on : PA-054
# working on : PA-055
# working on : PA-056
# working on : PA-057
# working on : PA-058
# working on : PA-059
# working on : PA-060
# Failed to process HR for: PA-060
# working on : PA-061
# working on : PA-062
# working on : PA-063
# working on : PA-064
# working on : PA-065
# working on : PA-067
# working on : PA-068
# working on : PA-069
# working on : PA-070
# working on : PA-071
# working on : PA-072
# working on : PA-073
# working on : PA-074
# working on : PA-075
# working on : PA-076
# working on : PA-077
# working on : PA-078
# working on : PA-079
# working on : PA-080
# working on : PA-081
# working on : PA-082
# working on : PA-083
# working on : PA-084
# working on : PA-085
# working on : PA-086
# working on : PA-087
# working on : PA-088
# working on : PA-089
# working on : PA-090
# working on : PA-091
# working on : PA-092
# working on : PA-093
# working on : PA-094
# working on : PA-095
# working on : PA-096
# working on : PA-097
# working on : PA-098
# working on : PA-099
# working on : PA-100
# working on : PA-101
# working on : PA-102
# working on : PA-103
# working on : PA-104
# working on : PA-105
# working on : PA-106
# working on : PA-107
# working on : PA-108
# Failed to process HR for: PA-108
# working on : PA-109
# working on : PA-110
# working on : PA-111
# working on : PA-112
# working on : PA-113
# working on : PA-114
# working on : PA-115
# working on : PA-116
# working on : PA-117
# working on : PA-118
# working on : PA-119
# working on : PA-120
# Failed to process HR for: PA-120
# working on : PA-121
# working on : PA-122
# working on : PA-123
# working on : PA-124
# working on : PA-125
# working on : PA-126
# working on : PA-127
# working on : PA-128
# working on : PA-129
# working on : PA-130
# working on : PA-131
# working on : PA-132
# working on : PA-133
# working on : PA-134
# working on : PA-135
# working on : PA-136
# working on : PA-137
# working on : PA-138
# working on : PA-139
# working on : PA-140
# working on : PA-141
# working on : PA-142
# working on : PA-143
# working on : PA-144
# working on : PA-145
# working on : PA-146
# working on : PA-147
# working on : PA-148
# working on : PA-149
# working on : PA-150
# working on : PA-151
# working on : PA-152
# working on : PA-153
# working on : PA-154
# working on : PA-155
# working on : PA-156
# working on : PA-157
# working on : PA-158 to PA-166
# working on : PA-167
# working on : PA-168
# Failed to process HR for: PA-168
# working on : PA-169
# working on : PA-170
# working on : PA-171
# working on : PA-172
# working on : PA-173
# working on : PA-174
# working on : PA-175
# working on : PA-176
# Failed to process HR for: PA-176
# working on : PA-177
# Failed to process HR for: PA-177
# working on : PA-178
# working on : PA-179
# working on : PA-180
# working on : PA-181
# working on : PA-182
# working on : PA-183
# working on : PA-184
# working on : PA-185
# working on : PA-186
# working on : PA-187
# working on : PA-188
# working on : PA-189
# working on : PA-190
# working on : PA-191
# working on : PA-192
# working on : PA-193
# working on : PA-194
# working on : PA-195
# working on : PA-196
# working on : PA-197
# working on : PA-198
# working on : PA-199
# working on : PA-200
# working on : PA-201
# working on : PA-202
# working on : PA-203
# working on : PA-204
# Failed to process HR for: PA-204
# working on : PA-205
# working on : PA-206
# working on : PA-207
# working on : PA-208
# working on : PA-209
# working on : PA-210
# working on : PA-211
# working on : PA-212
# working on : PA-213
# working on : PA-214
# working on : PA-215
# working on : PA-216
# Failed to process HR for: PA-216
# working on : PA-217
# working on : PA-218
# working on : PA-219
# working on : PA-220
# working on : PA-221
# working on : PA-222
# working on : PA-223
# working on : PA-224
# Failed to process HR for: PA-224
# working on : PA-225
# working on : PA-226
# working on : PA-227
# working on : PA-228
# Failed to process HR for: PA-228
# working on : PA-229
# working on : PA-230
# working on : PA-231
# working on : PA-232
# working on : PA-233
# working on : PA-234
# working on : PA-235
# working on : PA-236
# working on : PA-237
# working on : PA-238
# working on : PA-239
# working on : PA-240
# working on : PA-241
# Failed to process HR for: PA-241
# working on : PA-242
# working on : PA-243
# working on : PA-244
# working on : PA-245
# working on : PA-246
# working on : PA-247
# working on : PA-248
# working on : PA-249
# working on : PA-250
# working on : PA-251
# working on : PA-252
# working on : PA-253
# working on : PA-254
# working on : PA-255
# Failed to process HR for: PA-255
# working on : PA-256
# working on : PA-257
# Failed to process HR for: PA-257
# working on : PA-258
# working on : PA-259
# Failed to process HR for: PA-259
# working on : PA-260
# working on : PA-261
# working on : PA-262
# working on : PA-263
# working on : PA-264
# working on : PA-265
# working on : PA-266
# working on : PA-267
# working on : PA-268
# working on : PA-269
# working on : PA-270
# working on : PA-271
# working on : PA-272
# working on : PA-273
# working on : PA-274
# working on : PA-275
# working on : PA-276
# Failed to process HR for: PA-276
# working on : PA-277
# working on : PA-278
# working on : PA-279
# working on : PA-280
# working on : PA-281
# working on : PA-282
# working on : PA-283
# working on : PA-284
# working on : PA-285
# working on : PA-286
# working on : PA-287
# Failed to process HR for: PA-287
# working on : PA-288
# working on : PA-289
# working on : PA-290
# working on : PA-291
# working on : PA-292
# working on : PA-293
# working on : PA-294
# working on : PA-295
# working on : PA-296
# working on : PA-297
# working on : PA-298
# working on : PA-299
# working on : PA-300
# working on : PA-301
# working on : PA-302
# Failed to process HR for: PA-302
# working on : PA-303
# working on : PA-304
# working on : PA-305
# working on : PA-306
# working on : PA-307
# working on : PA-308
# working on : PA-309
# working on : RI-001
# working on : RI-002
# working on : RI-003
# working on : RI-004
# working on : RI-005
# working on : SC-001
# working on : SC-002
# working on : SC-003
# working on : SC-004
# working on : SC-005
# working on : SC-006
# working on : SC-007
# working on : SC-008
# working on : SC-009
# working on : SC-010
# working on : SC-011
# working on : SD-001
# working on : SD-004
# working on : SD-005
# working on : SD-012
# working on : SD-013
# working on : TN-001
# working on : TN-002
# working on : TN-003
# working on : TN-004
# working on : TN-005
# working on : TN-006
# working on : TN-007
# working on : TN-008
# working on : TN-009
# working on : TN-010
# working on : TN-011
# working on : TN-012
# working on : TN-013
# working on : TN-014
# working on : TN-015
# working on : TN-016
# working on : TN-018
# working on : TN-019
# working on : TN-020
# working on : TN-021
# working on : TN-022
# working on : TN-023
# working on : TX-001
# working on : TX-002
# working on : TX-003
# working on : TX-004
# working on : TX-005
# working on : TX-006
# working on : TX-007
# working on : TX-008
# working on : UT-001
# working on : UT-002
# working on : UT-003
# working on : UT-004
# working on : VA-001
# working on : VA-002
# working on : VA-003
# working on : VA-004
# working on : VA-005
# Failed to process HR for: VA-005
# working on : VA-006
# working on : VA-007
# working on : VA-008
# working on : VA-009
# working on : VA-010
# working on : VA-011
# working on : VA-012
# working on : VA-013
# working on : VA-014
# working on : VA-015
# working on : VA-016
# working on : VA-017
# working on : VA-018
# working on : VA-019
# working on : VA-020
# working on : VA-021
# working on : VA-022
# working on : VA-023
# Failed to process HR for: VA-023
# working on : VA-024
# working on : VA-025
# working on : VA-026
# working on : VA-027
# working on : VA-028
# working on : VA-029
# working on : VA-030
# working on : VA-031
# working on : VA-032
# working on : VA-033
# working on : VA-034
# working on : VT-001
# working on : VT-002
# working on : VT-003
# working on : VT-004
# working on : VT-005
# Failed to process HR for: VT-005
# working on : VT-006
# working on : VT-007
# working on : VT-008
# working on : VT-009
# working on : VT-010
# working on : VT-011
# working on : VT-012
# working on : VT-013
# working on : VT-014
# working on : VT-015
# working on : VT-016
# working on : VT-017
# working on : VT-018
# working on : VT-019
# working on : VT-020
# working on : VT-021
# working on : VT-022
# working on : VT-023
# working on : VT-024
# working on : VT-025
# working on : VT-026
# working on : VT-027
# working on : WA-001
# Failed to process HR for: WA-001
# working on : WA-002
# working on : WA-003
# working on : WA-004
# working on : WA-005
# working on : WA-006
# working on : WA-007
# working on : WA-008
# Failed to process HR for: WA-008
# working on : WA-009
# Failed to process HR for: WA-009
# working on : WA-010
# Failed to process HR for: WA-010
# working on : WA-011
# working on : WA-012
# working on : WA-013
# working on : WA-014
# working on : WA-015
# working on : WA-016
# working on : WA-017
# working on : WA-018
# working on : WA-019
# working on : WA-020
# working on : WA-021
# working on : WA-022
# working on : WA-023
# working on : WA-024
# working on : WA-025
# working on : WA-026
# working on : WA-027
# working on : WA-030
# Failed to process HR for: WA-030
# working on : WA-031
# working on : WA-032
# working on : WA-033
# working on : WI-001
# working on : WI-002
# working on : WI-003
# working on : WI-004
# working on : WI-005
# working on : WI-006
# working on : WI-007
# working on : WI-008
# working on : WI-009
# working on : WI-010
# working on : WI-011
# working on : WI-012
# working on : WI-013
# working on : WI-014
# working on : WI-015
# working on : WI-016
# working on : WI-017
# working on : WI-018
# working on : WI-019
# working on : WI-020
# working on : WI-021
# working on : WI-022
# working on : WI-023
# working on : WI-024
# working on : WI-025
# working on : WI-026
# working on : WI-027
# working on : WI-028
# working on : WI-029
# working on : WI-030
# working on : WI-031
# working on : WI-032
# working on : WI-033
# working on : WI-034
# working on : WI-035
# working on : WI-036
# working on : WI-037
# working on : WI-038
# working on : WI-039
# working on : WI-040
# working on : WI-041
# working on : WI-042
# working on : WI-043
# working on : WI-044
# working on : WI-045
# working on : WI-046
# working on : WI-047
# working on : WI-048
# working on : WI-049
# working on : WI-050
# working on : WI-051
# working on : WI-052
# working on : WI-053
# working on : WI-054
# working on : WI-055
# working on : WI-056
# working on : WI-057
# Failed to process HR for: WI-057
# working on : WI-058
# Failed to process HR for: WI-058
# working on : WI-059
# working on : WI-060
# working on : WI-061
# working on : WI-062
# working on : WI-063
# working on : WI-064
# working on : WI-065
# working on : WI-066
# working on : WI-067
# working on : WI-068
# working on : WI-069
# working on : WI-070
# working on : WI-071
# working on : WI-072
# working on : WI-073
# working on : WI-074
# working on : WI-075
# working on : WI-076
# working on : WI-077
# working on : WI-078
# working on : WI-079
# working on : WI-080
# working on : WI-081
# working on : WI-082
# working on : WI-083
# working on : WI-084
# working on : WI-085
# working on : WI-086
# working on : WI-087
# working on : WI-088
# working on : WI-089
# working on : WI-090
# working on : WI-091
# working on : WI-092
# working on : WI-093
# working on : WI-094
# working on : WI-095
# working on : WI-096
# working on : WI-097
# working on : WI-098
# working on : WI-099
# working on : WI-100
# working on : WI-101
# working on : WI-102
# Failed to process HR for: WI-102
# working on : WI-103
# working on : WI-104
# working on : WI-105
# working on : WI-106
# working on : WI-107
# working on : WI-108
# working on : WI-109
# working on : WI-110
# working on : WI-111
# working on : WI-112
# working on : WI-113
# working on : WI-114
# working on : WI-115
# working on : WI-116
# working on : WI-117
# working on : WI-118
# working on : WI-119
# working on : WI-120
# working on : WI-121
# working on : WI-122
# working on : WI-123
# working on : WI-124
# Failed to process HR for: WI-124
# working on : WI-125
# working on : WI-126
# working on : WI-127
# working on : WI-128
# working on : WI-129
# working on : WI-130
# working on : WI-131
# working on : WI-132
# working on : WI-133
# working on : WI-134
# working on : WI-135
# working on : WV-001
# working on : WV-002
# working on : WV-003
# Failed to process HR for: WV-003
# working on : WV-004
# working on : WY-001
# working on : WY-002
# working on : WY-003
# working on : WY-004
# working on : WY-005

# %%
outDf
# Out:
#           Comid   MeasHigh    MeasMed       ReachHigh        ReachMed  \
# 0      NO COMID -999.00000 -999.00000    NO REACHCODE    NO REACHCODE
# 1      NO COMID -999.00000 -999.00000    NO REACHCODE    NO REACHCODE
# 2      NO COMID -999.00000 -999.00000    NO REACHCODE    NO REACHCODE
# 3      NO COMID -999.00000 -999.00000    NO REACHCODE    NO REACHCODE
# 4      NO COMID -999.00000 -999.00000    NO REACHCODE    NO REACHCODE
# 5      NO COMID -999.00000 -999.00000    NO REACHCODE    NO REACHCODE
# 6      NO COMID -999.00000 -999.00000    NO REACHCODE    NO REACHCODE
# 7      NO COMID -999.00000 -999.00000    NO REACHCODE    NO REACHCODE
# 8      NO COMID -999.00000 -999.00000    NO REACHCODE    NO REACHCODE
# 9      21658128   63.09372   54.22023  03150202003380  03150202003380
# 10     NO COMID -999.00000 -999.00000    NO REACHCODE    NO REACHCODE
# 11      3435706 -999.00000   51.00162    NO REACHCODE  03130003000461
# 12     21657348 -999.00000   11.23402    NO REACHCODE  03150202000388
# 13     22203429 -999.00000   10.21637    NO REACHCODE  03150106000490
# 14     18565837   35.81973   35.74066  03160111000121  03160111000121
# 15     NO COMID -999.00000 -999.00000    NO REACHCODE    NO REACHCODE
# 16     NO COMID -999.00000 -999.00000    NO REACHCODE    NO REACHCODE
# 17      3676790 -999.00000   97.95395    NO REACHCODE  08020203001382
# 18      7627844 -999.00000   88.91648    NO REACHCODE  11010003001007
# 19     NO COMID -999.00000 -999.00000    NO REACHCODE    NO REACHCODE
# 20     NO COMID -999.00000 -999.00000    NO REACHCODE    NO REACHCODE
# 21     20438452 -999.00000   98.04692    NO REACHCODE  15060203000230
# 22     NO COMID -999.00000 -999.00000    NO REACHCODE    NO REACHCODE
# 23      8245912   89.82803   90.23370  18010211000143  18010211000143
# 24     NO COMID -999.00000 -999.00000    NO REACHCODE    NO REACHCODE
# 25     NO COMID -999.00000 -999.00000    NO REACHCODE    NO REACHCODE
# 26     22227536   28.04679   27.74249  18010101000239  18010101000239
# 27      8309124   20.16204   20.17680  18010103000869  18010103000869
# 28    948050045   19.71038   35.43390  18050005000108  18050005002515
# 29      5329491   64.72838   64.48498  18050005000135  18050005000135
# ...         ...        ...        ...             ...             ...
# 1340    6867263   94.65424   28.64912  04030201002438  04030201000646
# 1341    2649340   26.89481    0.80793  07030005005214  07030005000124
# 1342   13122138   97.93055   98.31985  07050001000674  07050001000674
# 1343   12162522   25.20090   28.02918  04040003000144  04040003000144
# 1344   14769062  100.00000   70.69727  07120006002247  07120006000721
# 1345   14769062   29.03083   50.36266  07120006002693  07120006000721
# 1346   12162558   13.77919   13.76132  04040003000517  04040003000517
# 1347   12162082  100.00000   69.81403  04040003000888  04040003000077
# 1348   13297038   18.21570   18.28632  07090002005024  07090002008323
# 1349   12163516 -999.00000   19.92468  04040003000052  04040003000052
# 1350    6801804    1.32186    2.52360  04030204001736  04030204002124
# 1351    6802160   78.56422    0.93798  04030204001687  04030204002253
# 1352   13291876   52.67971   98.45411  07090002006327  07090002007299
# 1353   13063335   27.26648   27.13939  04030102000085  04030102000085
# 1354   12177468  100.00000    0.00000  04060200001306  04040003003030
# 1355    6866861   17.24738   16.49010  04030201000517  04030201000517
# 1356    1798635   92.43323   91.14061  04010301000209  04010301000209
# 1357   14705004   59.10093   58.39375  07070003003054  07070003003054
# 1358    2261615   61.76217   99.70074  07030001003004  07030001000116
# 1359   14768740   73.64427   68.37782  07120006000109  07120006000109
# 1360   12177454   21.37503   21.88967  04030101000444  04030101000444
# 1361   NO COMID -999.00000 -999.00000    NO REACHCODE    NO REACHCODE
# 1362    3716252   77.32902   77.74817  05020002000088  05020002000088
# 1363    3716188 -999.00000    0.61880  05020002000085  05020002000086
# 1364    3716314 -999.00000   72.95178    NO REACHCODE  05020002000091
# 1365   NO COMID -999.00000 -999.00000    NO REACHCODE    NO REACHCODE
# 1366   NO COMID -999.00000 -999.00000    NO REACHCODE    NO REACHCODE
# 1367   NO COMID -999.00000 -999.00000    NO REACHCODE    NO REACHCODE
# 1368   23124939 -999.00000   45.57272    NO REACHCODE  17040101000751
# 1369   23130884   99.86557    2.18925  17040102003881  17040102000052
#
#          SmdateHigh  distCertMr  gnisCertMr             gnisNameM      id  \
# 0                             0         0.0                        AK-001
# 1                             0         0.0                        AK-002
# 2                             0         0.0                        AK-003
# 3                             0         0.0                        AK-004
# 4                             0         0.0                        AK-005
# 5                             0         0.0                        AK-006
# 6                             0         0.0                        AK-007
# 7                             0         0.0                        AK-008
# 8                             0         0.0                        AK-009
# 9     1330646400000           1         1.0          Cahaba River  AL-001
# 10                            0         0.0                        AL-002
# 11                            1         1.0           Uchee Creek  AL-003
# 12                            1         0.0          Shades Creek  AL-004
# 13                            1         1.0       Big Canoe Creek  AL-005
# 14     943056000000           1         1.0          Turkey Creek  AL-006
# 15                            0         0.0                        AR-001
# 16                            0         0.0                        AR-002
# 17                            0         1.0            Crow Creek  AR-003
# 18                            0         0.0  Little Georges Creek  AR-004
# 19                            0         0.0                        AZ-002
# 20                            0         0.0                        AZ-003
# 21                            1         1.0          Fossil Creek  AZ-004
# 22                            0         0.0                        CA-001
# 23     931824000000           1         1.0          Indian Creek  CA-002
# 24                            0         0.0                        CA-003
# 25                            0         0.0                        CA-004
# 26     929491200000           1         1.0          Monkey Creek  CA-005
# 27     930960000000           1         1.0            Salt Creek  CA-006
# 28     930960000000           1         0.0                  None  CA-007
# 29    1327363200000           1         0.0                  None  CA-008
# ...             ...         ...         ...                   ...     ...
# 1340  1331769600000           0         0.0                  None  WI-115
# 1341  1332028800000           1         1.0           Apple River  WI-116
# 1342  1330732800000           1         0.0                  None  WI-117
# 1343  1331769600000           1         0.0                  None  WI-118
# 1344  1332115200000           0         0.0                  None  WI-119
# 1345  1332115200000           0         0.0                  None  WI-120
# 1346   988934400000           1         1.0       Milwaukee River  WI-121
# 1347  1331769600000           1         1.0       Milwaukee River  WI-122
# 1348  1332028800000           1         1.0          Spring Brook  WI-123
# 1349                          1         1.0       Milwaukee River  WI-124
# 1350  1331769600000           1         1.0            Duck Creek  WI-125
# 1351  1331769600000           1         1.0            Duck Creek  WI-126
# 1352  1332028800000           1         1.0            Bark River  WI-127
# 1353   937180800000           1         1.0          Silver Creek  WI-128
# 1354  1371198777000           1         0.0                  None  WI-129
# 1355  1331769600000           1         0.0                  None  WI-130
# 1356  1330732800000           1         1.0          Poplar River  WI-131
# 1357  1450683937000           1         0.0                  None  WI-132
# 1358  1330732800000           1         1.0      Eau Claire River  WI-133
# 1359   939945600000           1         1.0           White River  WI-134
# 1360  1331769600000           1         0.0                  None  WI-135
# 1361                          0         0.0                        WV-001
# 1362  1332720000000           1         1.0       West Fork River  WV-002
# 1363                          1         1.0       West Fork River  WV-003
# 1364                          0         1.0       West Fork River  WV-004
# 1365                          0         0.0                        WY-001
# 1366                          0         0.0                        WY-002
# 1367                          0         0.0                        WY-003
# 1368                          0         0.0                  None  WY-004
# 1369  1326844800000           1         1.0     Gros Ventre River  WY-005
#
#                                     permIdHr  \
# 0                                 NO PERM ID
# 1                                 NO PERM ID
# 2                                 NO PERM ID
# 3                                 NO PERM ID
# 4                                 NO PERM ID
# 5                                 NO PERM ID
# 6                                 NO PERM ID
# 7                                 NO PERM ID
# 8                                 NO PERM ID
# 9     {AF1DF2AD-843B-48B8-AC66-AE5B737BA274}
# 10                                NO PERM ID
# 11                                NO PERM ID
# 12                                NO PERM ID
# 13                                NO PERM ID
# 14    {FDA890D0-E03D-4878-9536-D3E624E8B65B}
# 15                                NO PERM ID
# 16                                NO PERM ID
# 17                                NO PERM ID
# 18                                NO PERM ID
# 19                                NO PERM ID
# 20                                NO PERM ID
# 21                                NO PERM ID
# 22                                NO PERM ID
# 23    {6E05CFF5-8515-46D8-A1AB-779675FA3EF3}
# 24                                NO PERM ID
# 25                                NO PERM ID
# 26    {03CE321E-C9CA-43F7-8904-1EABCFA4440F}
# 27    {9E2C5352-CCC2-4429-91F7-C79E3FD4EA27}
# 28    {DD4BEBCE-30E9-4729-8434-242979318D08}
# 29    {E63440DB-A816-44DE-8F40-50BD4B34F499}
# ...                                      ...
# 1340  {1846D40C-24FE-4069-932F-87BDA2BC63DC}
# 1341  {0A0ED1FE-69DF-4DCB-B32C-E45B5FAD2135}
# 1342  {D96ABF05-CD95-4BA7-BC46-69FF4BD095F2}
# 1343  {BA16B91C-A381-4134-B922-59814E576E6F}
# 1344  {AD5A0CC0-EC8E-4879-A700-86B4D31C6524}
# 1345  {D70A2456-B1EA-4BCA-9842-FDC76D83171C}
# 1346  {D3779393-4CBC-477D-944E-CFABD3AE71E0}
# 1347  {A581A665-C5DA-439E-9AE0-AE409A808B15}
# 1348  {FA681495-4A8C-4F57-958D-8595333978D5}
# 1349                              NO PERM ID
# 1350  {FDC5A09A-30AE-4288-AF3D-2D30F675D43C}
# 1351  {C9C62B70-9222-464B-B360-3D126B8F36C3}
# 1352  {63AA3DD5-8FE2-434D-BC8F-EE51878CE623}
# 1353  {62E06485-C686-4D90-A02D-3A6C20578574}
# 1354  {924FDC4C-CE84-47C9-82A4-952ABB69D73C}
# 1355  {8DC41D3F-A5A2-4427-AF21-F96F4D4A10AA}
# 1356  {4A2CD0FC-0A73-4D44-898D-B7C817198400}
# 1357  {E8E24B54-6EE8-4FDB-A329-0BF723073E93}
# 1358  {9870E822-86BB-452C-80FE-8A88E5A88C6F}
# 1359  {66D54727-6D06-4F9E-8037-389BF07D595A}
# 1360  {0779A665-424A-45DC-93DA-2D0E52CBE71B}
# 1361                              NO PERM ID
# 1362  {2F0228A1-41CF-4B83-9A57-4BB933D3C907}
# 1363                              NO PERM ID
# 1364                              NO PERM ID
# 1365                              NO PERM ID
# 1366                              NO PERM ID
# 1367                              NO PERM ID
# 1368                              NO PERM ID
# 1369  {DD0C01E3-23EF-4EB1-8174-E3F7A4D1069C}
#
#                                                  xyHigh  \
# 0                                                  -999
# 1                                                  -999
# 2                                                  -999
# 3                                                  -999
# 4                                                  -999
# 5                                                  -999
# 6                                                  -999
# 7                                                  -999
# 8                                                  -999
# 9     {'x': -87.029659830529, 'y': 33.16560553685197...
# 10                                                 -999
# 11                                                 -999
# 12                                                 -999
# 13                                                 -999
# 14    {'x': -86.64633410928127, 'y': 33.682848881050...
# 15                                                 -999
# 16                                                 -999
# 17                                                 -999
# 18                                                 -999
# 19                                                 -999
# 20                                                 -999
# 21                                                 -999
# 22                                                 -999
# 23    {'x': -122.90824197905363, 'y': 40.63822913487...
# 24                                                 -999
# 25                                                 -999
# 26    {'x': -123.81495446370867, 'y': 41.89024929782...
# 27    {'x': -122.79482749977541, 'y': 39.29304380567...
# 28    {'x': -122.91761312263894, 'y': 38.06924691137...
# 29    {'x': -122.90437171966818, 'y': 38.08528667421...
# ...                                                 ...
# 1340  {'x': -89.64125357129922, 'y': 43.670533932214...
# 1341  {'x': -92.36371795172778, 'y': 45.396468994534...
# 1342  {'x': -91.38802632375265, 'y': 45.570137800512...
# 1343  {'x': -87.9897930106656, 'y': 43.2348727061293...
# 1344  {'x': -88.47417597311073, 'y': 42.827095600190...
# 1345  {'x': -88.47374170644474, 'y': 42.834426866845...
# 1346  {'x': -87.9533984036449, 'y': 43.3051424785040...
# 1347  {'x': -88.27084610675968, 'y': 43.598930998992...
# 1348  {'x': -89.00056933903987, 'y': 42.511957626964...
# 1349                                               -999
# 1350  {'x': -88.11088529942643, 'y': 44.540954144834...
# 1351  {'x': -88.10168334639182, 'y': 44.545816521690...
# 1352  {'x': -88.42242465671927, 'y': 43.059363331190...
# 1353  {'x': -87.47170329130957, 'y': 44.607842516994...
# 1354  {'x': -87.8959271740083, 'y': 43.1970795996161...
# 1355  {'x': -89.304444371822, 'y': 43.92076779849282...
# 1356  {'x': -91.79363450129159, 'y': 46.579353527699...
# 1357  {'x': -89.84678276814564, 'y': 44.329445580759...
# 1358  {'x': -91.7839659013066, 'y': 46.2372075282305...
# 1359  {'x': -88.42557822943688, 'y': 42.599280460953...
# 1360  {'x': -87.87771013608287, 'y': 43.382180609454...
# 1361                                               -999
# 1362  {'x': -80.3770404256436, 'y': 39.2210876476600...
# 1363                                               -999
# 1364                                               -999
# 1365                                               -999
# 1366                                               -999
# 1367                                               -999
# 1368                                               -999
# 1369  {'x': -110.62478312965789, 'y': 43.62002040126...
#
#                                       xyMed
# 0                  POINT(-152.395 57.80333)
# 1                  POINT(-152.395 57.80167)
# 2                 POINT(-149.4267 62.61833)
# 3                   POINT(-149.38 62.62667)
# 4                            POINT(nan nan)
# 5                      POINT(-134.5 58.365)
# 6                POINT(-133.93099 56.98154)
# 7              POINT(-146.404303 65.292798)
# 8                            POINT(nan nan)
# 9     [-87.0294274247695, 33.1656451163403]
# 10                           POINT(nan nan)
# 11    [-85.1215534712747, 32.3639817436015]
# 12    [-87.0328987457601, 33.2195650764026]
# 13     [-86.385264540615, 33.8197072863833]
# 14    [-86.6463741679883, 33.6827778624098]
# 15                           POINT(nan nan)
# 16                           POINT(nan nan)
# 17    [-90.7601102971736, 35.0715113755914]
# 18    [-92.7106780327643, 36.2680276105867]
# 19                           POINT(nan nan)
# 20                           POINT(nan nan)
# 21    [-111.576084625894, 34.4213339810531]
# 22                           POINT(nan nan)
# 23    [-122.908365335474, 40.6381356946306]
# 24                           POINT(nan nan)
# 25                           POINT(nan nan)
# 26    [-123.815044620474, 41.8904641585422]
# 27    [-122.794821767885, 39.2930631419105]
# 28    [-122.917600769213, 38.0693675034175]
# 29    [-122.904477329739, 38.0853417404045]
# ...                                     ...
# 1340  [-89.6419124330175, 43.6702874700486]
# 1341  [-92.3638709219054, 45.3964348789109]
# 1342  [-91.3879002583177, 45.5701760923953]
# 1343  [-87.9897619067859, 43.2350019324941]
# 1344  [-88.4724051528747, 42.8268933130723]
# 1345  [-88.4703001063642, 42.8326164006273]
# 1346  [-87.9532115389495, 43.3051308702957]
# 1347  [-88.2710902226492, 43.5990320547212]
# 1348  [-89.0006320083431, 42.5120852319301]
# 1349  [-88.0490361978599, 43.4341337374864]
# 1350    [-88.110905838935, 44.540890568763]
# 1351  [-88.1017894453562, 44.5459301863768]
# 1352   [-88.4223562731226, 43.059181038503]
# 1353  [-87.4716952438966, 44.6077679644441]
# 1354  [-87.8960953744013, 43.1970279331935]
# 1355   [-89.304713791285, 43.9208305165966]
# 1356   [-91.7935659387635, 46.579381604155]
# 1357  [-89.8468558106534, 44.3294467421672]
# 1358   [-91.7839701109645, 46.237159025651]
# 1359  [-88.4254512180187, 42.5992304945805]
# 1360  [-87.8775506738889, 43.3819819083726]
# 1361                         POINT(nan nan)
# 1362  [-80.3770683716682, 39.2210669540121]
# 1363  [-80.3579533381908, 39.2388919084674]
# 1364  [-80.4060785188079, 39.1984654724045]
# 1365                         POINT(nan nan)
# 1366                         POINT(nan nan)
# 1367                         POINT(nan nan)
# 1368  [-110.473615610465, 43.7884175220788]
# 1369  [-110.624769886666, 43.6200127133711]
#
# [1370 rows x 13 columns]

# %%
outFile = input("Name of output file. No extension:  ")
outFile = outFile + ".csv"
outDf.to_csv(outFile)
# Out:
# Name of output file. No extension:  arRivBasin
